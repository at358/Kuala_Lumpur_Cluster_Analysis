# %%
# !pip install folium==0.5.0
! pip install geocoder


import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import json # library to handle JSON files

import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML and XML documents

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print("Libraries imported.")
# Out:
# Requirement already satisfied: folium==0.5.0 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (0.5.0)
# Requirement already satisfied: jinja2 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: branca in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: geocoder in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (1.38.1)
# Requirement already satisfied: six in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: ratelim in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: click in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: future in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from requests->geocoder) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from requests->geocoder) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: decorator in c:\users\sheej.desktop-sdf1007\onedrive\documents\anaconda_python\lib\site-packages (from ratelim->geocoder) (4.4.2)
# Libraries imported.

# %%
data = requests.get("https://en.wikipedia.org/wiki/Category:Suburbs_in_Kuala_Lumpur").text
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# create a list to store neighborhood data
neighborhoodList = []

# append the data into the list
for row in soup.find_all("div", class_="mw-category")[0].findAll("li"):
    neighborhoodList.append(row.text)

# create a new DataFrame from the list
kl_df = pd.DataFrame({"Neighborhood": neighborhoodList})

kl_df.head(50)
# Out:
#                     Neighborhood
# 0                     Alam Damai
# 1           Ampang, Kuala Lumpur
# 2               Bandar Menjalara
# 3          Bandar Sri Permaisuri
# 4           Bandar Tasik Selatan
# 5               Bandar Tun Razak
# 6                        Bangsar
# 7                   Bangsar Park
# 8                  Bangsar South
# 9                 Batu 11 Cheras
# 10            Batu, Kuala Lumpur
# 11                   Brickfields
# 12                 Bukit Bintang
# 13                   Bukit Jalil
# 14                   Bukit Kiara
# 15                   Bukit Nanas
# 16                Bukit Petaling
# 17                   Bukit Tunku
# 18          Cheras, Kuala Lumpur
# 19                      Chow Kit
# 20             Damansara Heights
# 21         Damansara Town Centre
# 22                    Dang Wangi
# 23                 Desa Petaling
# 24    Federal Hill, Kuala Lumpur
# 25                  Happy Garden
# 26  Jalan Cochrane, Kuala Lumpur
# 27                       Jinjang
# 28    Kampung Baru, Kuala Lumpur
# 29         Kampung Datuk Keramat
# 30            Kampung Kasipillay
# 31         Kampung Padang Balang
# 32                        Kepong
# 33                   Kepong Baru
# 34                   KL Eco City
# 35                   Kuchai Lama
# 36                 Lembah Pantai
# 37                        Maluri
# 38                  Medan Tuanku
# 39                       Miharja
# 40                    Mont Kiara
# 41                  Pantai Dalam
# 42            Pudu, Kuala Lumpur
# 43                     Putrajaya
# 44                   Salak South
# 45                      Segambut
# 46                       Semarak
# 47          Sentul, Kuala Lumpur
# 48                       Setapak
# 49                   Setiawangsa
